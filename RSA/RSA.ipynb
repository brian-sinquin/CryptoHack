# %%
import numpy as np
from urllib import request
from hashlib import sha256

from Crypto.Util.number import bytes_to_long

# %%
# Starter 1
sol = pow(base=101, exp=17, mod=22663)
print(sol)

# OK
# Out:
# 19906

# %%
# Starter 2

e = 65537 # exponent
p = 17 
q = 23

N = p*q # modulus

n = 12 # base

sol = pow(base=n, exp=e, mod=N)
print(sol)

# OK
# Out:
# 301

# %%
# Starter 3

p = 857504083339712752489993810777
q = 1029224947942998075080348647219

φ = (p-1)*(q-1) # definition
print(φ)

# OK
# Out:
# 882564595536224140639625987657529300394956519977044270821168

# %%
# Starter 4

p = 857504083339712752489993810777
q = 1029224947942998075080348647219

N = p*q 
φ = (p-1)*(q-1)

e = 65537

d = pow(e, -1,φ)

print(d)
# OK
# Out:
# 121832886702415731577073962957377780195510499965398469843281
# True

# %%
# Starter 5 

N = 882564595536224140639625987659416029426239230804614613279163
# public key 

e = 65537 # exponent

c = 77578995801157823671636298847186723593814843845525223303932 

# use previous private key from ex. 4
sol = pow(c, d, N)

print(sol)

# OK
# Out:
# 13371337

# %%
# Starter 6

d = ...
N = ...

M_bytes = b"crypto{Immut4ble_m3ssag1ng}"
M_hash = sha256(M_bytes)
M = int.from_bytes(M_hash.digest(), 'big')


Ssol = pow(M, d, N)

print(Ssol)

# OK
# Out:
# ...

# %%
import primefac

# %%
# Factoring

N = 510143758735509025530880200653196460532653147

#l = primefac.siqs(N)
l = 19704762736204164635843

p = l 
q = N//p

sol = min(p,q)

print(sol)
# OK
# Out:
# 19704762736204164635843

# %%
# Inferius Prime


from Crypto.Util.number import getPrime, inverse, bytes_to_long, long_to_bytes, GCD

# e = 3

# # n will be 8 * (100 + 100) = 1600 bits strong which is pretty good
# while True:
#     p = getPrime(100)
#     q = getPrime(100)
#     phi = (p - 1) * (q - 1)
#     d = inverse(e, phi)
#     if d != -1 and GCD(e, phi) == 1:
#         break

# n = p * q

# flag = b"XXXXXXXXXXXXXXXXXXXXXXX"
# pt = bytes_to_long(flag)
# ct = pow(pt, e, n)

# print(f"n = {n}")
# print(f"e = {e}")
# print(f"ct = {ct}")

# pt = pow(ct, d, n)
# decrypted = long_to_bytes(pt)
# assert decrypted == flag


# Output

n = 742449129124467073921545687640895127535705902454369756401331


# find p and q on factor dB
p = 752708788837165590355094155871
q = 986369682585281993933185289261

φ = (p-1)*(q-1)
e = 3 

d = pow(e, -1,φ)

ct = 39207274348578481322317340648475596807303160111338236677373

m = pow(ct, d, n)

m_str = long_to_bytes(m)

print(m_str)

# OK
# Out:
# b'crypto{N33d_b1g_pR1m35}'

# %%
# Monoprime

n =                                                                   
e = 65537
ct =   

# we now that n is made of one unique prime
φ = n-1

d = pow(e, -1, φ)

m = pow(ct, d, n)

m_str = long_to_bytes(m)

print(m_str)

# OK
# Out:
# b'crypto{0n3_pr1m3_41n7_pr1m3_l0l}'

# %%
# Square Eyes



# N is made of one unique 2048 bit prime number used twice
# N = q^2 

n = ...
e = 65537
ct = ...

# sqrt(n) == prime obtained on factordb
q = ...


φ = q*(q-1)



d = pow(e, -1, φ)

m = pow(ct, d, n)

m_str = long_to_bytes(m)

print(m_str)


#OK
# Out:
# b'crypto{squar3_r00t_i5_f4st3r_th4n_f4ct0r1ng!}'
# True

# %%
# Manyprimes

n = ...
e = 65537
ct = ...

# n is composed of 30 prime number (factor db)
# could use Sage with ecm algorithm from ressources


factors = [
    9282105380008121879, 9303850685953812323, 9389357739583927789, 10336650220878499841, 10638241655447339831, 11282698189561966721, 11328768673634243077, 11403460639036243901, 11473665579512371723, 11492065299277279799, 11530534813954192171, 11665347949879312361, 12132158321859677597, 12834461276877415051, 12955403765595949597, 12973972336777979701, 13099895578757581201, 13572286589428162097, 14100640260554622013, 14178869592193599187, 14278240802299816541, 14523070016044624039, 14963354250199553339, 15364597561881860737, 15669758663523555763, 15824122791679574573, 15998365463074268941, 16656402470578844539, 16898740504023346457, 17138336856793050757, 17174065872156629921, 17281246625998849649
]

φ = 1

for f in factors :
    φ = φ*(f-1)

d = pow(e, -1, φ)

m = pow(ct, d, n)

m_str = long_to_bytes(m)

print(m_str)

# OK
# Out:
# b'crypto{700_m4ny_5m4ll_f4c70r5}'

# %%
# Salty
# hint : Smallest exponent should be fastest, right?


""" from Crypto.Util.number import getPrime, inverse, bytes_to_long, long_to_bytes

e = 1
d = -1

while d == -1:
    p = getPrime(512)
    q = getPrime(512)
    phi = (p - 1) * (q - 1)
    d = inverse(e, phi)

n = p * q

flag = b"XXXXXXXXXXXXXXXXXXXXXXX"
pt = bytes_to_long(flag)
ct = pow(pt, e, n)

print(f"n = {n}")
print(f"e = {e}")
print(f"ct = {ct}")

pt = pow(ct, d, n)
decrypted = long_to_bytes(pt)
assert decrypted == flag """

n =                                                                   
e = 1
ct = 44981230718212183604274785925793145442655465025264554046028251311164494127485


d = e 

m = pow(ct, d, n)

m_str = long_to_bytes(m)

print(m_str)

# OK
# Out:
# b'crypto{saltstack_fell_for_this!}'

# %%
# Modulus Inutilitis

# hint : My primes should be more than large enough now!
# low exponent weakness attack
# https://www.areizen.fr/post/rsa_low_exponent_attack/

from Crypto.Util.number import getPrime, inverse, bytes_to_long, long_to_bytes
import libnum
"""
e = 3
d = -1

while d == -1:
    p = getPrime(1024)
    q = getPrime(1024)
    phi = (p - 1) * (q - 1)
    d = inverse(e, phi)

n = p * q

flag = b"XXXXXXXXXXXXXXXXXXXXXXX"
pt = bytes_to_long(flag)
ct = pow(pt, e, n)

print(f"n = {n}")
print(f"e = {e}")
print(f"ct = {ct}")

pt = pow(ct, d, n)
decrypted = long_to_bytes(pt)
assert decrypted == flag """

n = ...
e = 3
ct = 243251053617903760309941844835411292373350655973075480264001352919865180151222189820473358411037759381328642957324889519192337152355302808400638052620580409813222660643570085177957

m = libnum.nroot(ct,3)

m_str = long_to_bytes(m)
print(m_str)
# Out:
# b'crypto{N33d_m04R_p4dd1ng}'

# %%
# Everything is Big
# hint : We have a supercomputer at work, so I've made sure my encryption is secure by picking massive numbers!

# --> Wiener attack 
from Crypto.Util.number import getPrime, bytes_to_long, long_to_bytes
import owiener

"""
from Crypto.Util.number import getPrime, bytes_to_long

FLAG = b"crypto{?????????????????????????}"

m = bytes_to_long(FLAG)

def get_huge_RSA():
    p = getPrime(1024)
    q = getPrime(1024)
    N = p*q
    phi = (p-1)*(q-1)
    while True:
        d = getPrime(256)
        e = pow(d,-1,phi)
        if e.bit_length() == N.bit_length():
            break
    return N,e


N, e = get_huge_RSA()
c = pow(m, e, N)

print(f'N = {hex(N)}')
print(f'e = {hex(e)}')
print(f'c = {hex(c)}')
"""



N = ...
e = ...
c = ...

# see https://www.ams.org/notices/199902/boneh.pdf
d = owiener.attack(e,N)

m = pow(c, d, N)

m_str = long_to_bytes(m)

print(m_str)

# OK
# Out:
# b'crypto{s0m3th1ng5_c4n_b3_t00_b1g}'

# %%
# Crossed Wires
# hint: I asked my friends to encrypt our secret flag before sending it to me, but instead of using my key, they've all used their own! Can you help?
from gmpy2 import invert
"""
from Crypto.Util.number import getPrime, long_to_bytes, bytes_to_long, inverse
import math
from gmpy2 import next_prime

FLAG = b"crypto{????????????????????????????????????????????????}"

p = getPrime(1024)
q = getPrime(1024)
N = p*q
phi = (p-1)*(q-1)
e = 0x10001
d = inverse(e, phi)

my_key = (N, d)

friends = 5
friend_keys = [(N, getPrime(17)) for _ in range(friends)]

cipher = bytes_to_long(FLAG)

for key in friend_keys:
    cipher = pow(cipher, key[1], key[0])

print(f"My private key: {my_key}")
print(f"My Friend's public keys: {friend_keys}")
print(f"Encrypted flag: {cipher}")
"""

from Crypto.Util.number import *

# N, d useless because this key was not used
ne = (..., ...)
N = ...
ne=[(..., 106979), (..., 108533), (..., 69557), (..., 97117), (..., 103231)]
c =...
f_d = []
# N gives p and q (factor db)

p = 
q = 

phi = (p-1)*(q-1)



f_e = []


for k in ne : 
    f_e.append(k[1])
for e in f_e :
    d = pow(e, -1 , phi)
    c = pow(c, d, N)

print(long_to_bytes(c))

# OK 

# They used different e but the same N and encoded the signal each after the other
# By factorizing N and knowing e, it is possible de know d and decode the signal at each stage

# a better name for the problem would be "The friendly ognon encoding"
# Out:
# b'crypto{3ncrypt_y0ur_s3cr3t_w1th_y0ur_fr1end5_publ1c_k3y}'

# %%
# Everything is still big 

"""
from Crypto.Util.number import getPrime, bytes_to_long, inverse
from random import getrandbits
from math import gcd

FLAG = b"crypto{?????????????????????????????????????}"

m = bytes_to_long(FLAG)

def get_huge_RSA():
    p = getPrime(1024)
    q = getPrime(1024)
    N = p*q
    phi = (p-1)*(q-1)
    while True:
        d = getrandbits(512)
        if (3*d)**4 > N and gcd(d,phi) == 1:
            e = inverse(d, phi)
            break
    return N,e


N, e = get_huge_RSA()
c = pow(m, e, N)

print(f'N = {hex(N)}')
print(f'e = {hex(e)}')
print(f'c = {hex(c)}')
"""


N = ...
e = ...
c = ...

import owiener 


d = owiener.attack(e, N)

m = pow(c, d, N)

print(long_to_bytes(m))

# OK
# Out:
# b'crypto{bon3h5_4tt4ck_i5_sr0ng3r_th4n_w13n3r5}'

# %%
# Endless emails

from Crypto.Util.number import long_to_bytes
import libnum
import owiener
import modint
from functools import reduce
import gmpy2

# list of (n,e,c)

n1 = ...
e1 = 3
c1 = ...


n2 = ...
e2 = 3
c2 = ...


n3 = ...
e3 = 3
c3 = ...


n4 = ...
e4 = 3
c4 = ...


n5 = ...
e5 = 3
c5 = ...


n6 = ...
e6 = 3
c6 = ...


n7 = ...
e7 = 3
c7 = ...


# weak e attack ?
# we know that all cyphers encode an unique and same msg ?
# see theorem 8 of https://www.ams.org/notices/199902/boneh.pdf


# Broadcast attack 
# Chinese remainder theorem

# N = n5*n6*n7
 
# N1 = N//n5
# N2 = N//n2
# N3 = N//n3

# u1 = gmpy2.invert(N1, n1)
# u2 = gmpy2.invert(N2, n2)
# u3 = gmpy2.invert(N3, n3)

# ff = pow(N1, -1, n1)

# print(ff==u1)
# C = (c5*u1*N1 + c6*u2*N2 + c7*u3*N3) % N

# m = libnum.nroot(C,3)


def chinese_remainder(n, a):
    sum = 0
    prod = reduce(lambda a, b: a*b, n)

    for n_i, a_i in zip(n, a):
        p = prod // n_i
        sum += a_i * mul_inv(p, n_i) * p
    return sum % prod


def mul_inv(a, b):
    b0 = b
    x0, x1 = 0, 1
    if b == 1: return 1
    while a > 1:
        q = a // b
        a, b = b, a%b
        x0, x1 = x1 - q * x0, x0
    if x1 < 0: x1 += b0
    return x1

def find_invpow(x,n):
    high = 1
    while high ** n < x:
        high *= 2
    low = high//2
    while low < high:
        mid = (low + high) // 2
        if low < mid and mid**n < x:
            low = mid
        elif high > mid and mid**n > x:
            high = mid
        else:
            return mid
    return mid + 1

n = [n3,n1,n6]
a = [c3,c1,c6]

result = chinese_remainder(n, a)
m = libnum.nroot(result,3)


print(long_to_bytes(m))

# OK
# Out:
# b'yes\n\n---\n\nJohan Hastad\nProfessor in Computer Science in the Theoretical Computer Science\nGroup at the School of Computer Science and Communication at KTH Royal Institute of Technology in Stockholm, Sweden.\n\ncrypto{1f_y0u_d0nt_p4d_y0u_4r3_Vuln3rabl3}'

# %%
# Algorithm of previous one with other data

import gmpy2

e = 3

n1 = 
n2 = 
n3 = 

c1 = 
c2 = 
c3 = 

N = n1*n2*n3
N1 = N//n1
N2 = N//n2
N3 = N//n3

u1 = gmpy2.invert(N1, n1)
u2 = gmpy2.invert(N2, n2)
u3 = gmpy2.invert(N3, n3)

M = (c1*u1*N1 + c2*u2*N2 + c3*u3*N3) % N

m = libnum.nroot(M,e)

print(long_to_bytes(m))
# Out:
# b'theoretical_computer_scientist_johan_torkel_hastad'

# %%
# Infinite descent

from Crypto.Util.number import long_to_bytes

n = ...
e = 65537
c = ...

import gmpy2 

# p & q are close so we can use the fermat algorithm to factorize n

def fermatFactor(n: int, max_steps: int):
    if n % 2 == 0:
        return 2, n // 2

    a = gmpy2.isqrt(n)

    if a * a == n:
        return a, a

    a += 1  # ceil(sqrt(n))
    b2 = a * a - n

    for _ in range(max_steps):
        if gmpy2.is_square(b2):
            return a + gmpy2.isqrt(b2), a - gmpy2.isqrt(b2)

        b2 += a
        a += 1
        b2 += a
    return None

p,q = fermatFactor(n, 100)

phi = (p-1)*(q-1)
d = pow(e,-1,phi)
M = pow(c, d, n)


print(long_to_bytes(M))

# OK
# Out:
# b'crypto{f3rm47_w45_4_g3n1u5}'
